# %% [markdown]
# <a href="https://colab.research.google.com/github/ronish645/Ronish380/blob/main/Module11_Ronish(19707)_Lab11_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy

# %% [markdown]
# ### Step 2. Read the Data `Student_Alcohol_Consumption.csv` and Assign it to a variable called df.

# %%
df = pd.read_csv('Student_Alcohol_Consumption.csv', index_col = 0)

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (395, 33)

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# ### Step 3. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
dfsub = df.loc[:,'school':'guardian']

# %% [markdown]
# ### Step 4. Create a lambda function that will capitalize strings.

# %%
lamcap = lambda x: x.capitalize()

# %%
lamcap('yasin')
# Out:
# 'Yasin'

# %% [markdown]
# ### Step 5. Capitalize both Mjob and Fjob

# %%
dfsub.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
# 4    home   father

# %%
dfsub.Mjob = dfsub.Mjob.apply(lamcap)

# %%
dfsub.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  At_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  At_home     other
# 2     GP   F   15       U     LE3       T     1     1  At_home     other
# 3     GP   F   15       U     GT3       T     4     2   Health  services
# 4     GP   F   16       U     GT3       T     3     3    Other     other
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
# 4    home   father

# %%
dfsub.Fjob = dfsub.Fjob.apply(lamcap)

# %%
dfsub.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  At_home   Teacher
# 1     GP   F   17       U     GT3       T     1     1  At_home     Other
# 2     GP   F   15       U     LE3       T     1     1  At_home     Other
# 3     GP   F   15       U     GT3       T     4     2   Health  Services
# 4     GP   F   16       U     GT3       T     3     3    Other     Other
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
# 4    home   father

# %% [markdown]
# ### Step 6. Print the last elements of the data set.

# %%
dfsub.tail(10)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 385     MS   F   18       R     GT3       T     2     2   At_home     Other
# 386     MS   F   18       R     GT3       T     4     4   Teacher   At_home
# 387     MS   F   19       R     GT3       T     2     3  Services     Other
# 388     MS   F   18       U     LE3       T     3     1   Teacher  Services
# 389     MS   F   18       U     GT3       T     1     1     Other     Other
# 390     MS   M   20       U     LE3       A     2     2  Services  Services
# 391     MS   M   17       U     LE3       T     3     1  Services  Services
# 392     MS   M   21       R     GT3       T     1     1     Other     Other
# 393     MS   M   18       R     LE3       T     3     2  Services     Other
# 394     MS   M   19       U     LE3       T     1     1     Other   At_home
#
#          reason guardian
# 385       other   mother
# 386  reputation   mother
# 387      course   mother
# 388      course   mother
# ...

# %% [markdown]
# ### Step 7. Create a function called majority that returns a boolean value to a new column called legal_drinker (Consider majority as older than 17 years old)

# %%
def majorty(x):
  if x>17:
    return True
  else:
    return False

# %%
dfsub['legal_drinker']=dfsub.age.apply(majorty)

# %%
dfsub.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  At_home   Teacher
# 1     GP   F   17       U     GT3       T     1     1  At_home     Other
# 2     GP   F   15       U     LE3       T     1     1  At_home     Other
# 3     GP   F   15       U     GT3       T     4     2   Health  Services
# 4     GP   F   16       U     GT3       T     3     3    Other     Other
#
#    reason guardian  legal_drinker
# 0  course   mother           True
# 1  course   father          False
# 2   other   mother          False
# 3    home   mother          False
# 4    home   father          False

# %%
majorlam = lambda x: True if x>17 else False

# %%
dfsub['legal_drinker2']=dfsub.age.apply(majorlam)

# %%
dfsub.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  At_home   Teacher
# 1     GP   F   17       U     GT3       T     1     1  At_home     Other
# 2     GP   F   15       U     LE3       T     1     1  At_home     Other
# 3     GP   F   15       U     GT3       T     4     2   Health  Services
# 4     GP   F   16       U     GT3       T     3     3    Other     Other
#
#    reason guardian  legal_drinker  legal_drinker2
# 0  course   mother           True            True
# 1  course   father          False           False
# 2   other   mother          False           False
# 3    home   mother          False           False
# 4    home   father          False           False

# %% [markdown]
# ### Step 8. Multiply every number of the dataset by 10.

# %%
def time10 (x):
  if type(x) in [int, float]:
    return 10*x
  else:
    return x

# %%
x = 5.4
type(x)
# Out:
# float

# %%
time10(x)
# Out:
# 54.0

# %%
for i in list(dfsub.columns):
  print(i)
  dfsub[i] = dfsub[i].apply(time10)
# Out:
# school
# sex
# age
# address
# famsize
# Pstatus
# Medu
# Fedu
# Mjob
# Fjob
# reason
# guardian
# legal_drinker
# legal_drinker2

# %%
dfsub.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F  180       U     GT3       A    40    40  At_home   Teacher
# 1     GP   F  170       U     GT3       T    10    10  At_home     Other
# 2     GP   F  150       U     LE3       T    10    10  At_home     Other
# 3     GP   F  150       U     GT3       T    40    20   Health  Services
# 4     GP   F  160       U     GT3       T    30    30    Other     Other
#
#    reason guardian  legal_drinker  legal_drinker2
# 0  course   mother           True            True
# 1  course   father          False           False
# 2   other   mother          False           False
# 3    home   mother          False           False
# 4    home   father          False           False
