# %% [markdown]
# <a href="https://colab.research.google.com/github/ronish645/Ronish380/blob/main/PandasDataManipulation1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
meteor = pd.read_csv('Meteorite_Landings.csv')
meteor.shape
meteor.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                      year    reclat    reclong           GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775, 6.08333)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333  (56.18333, 10.23333)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000    (54.21667, -113.0)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000     (16.88333, -99.9)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000   (-33.16667, -64.95)

# %%
meteor.columns      #what are the column names?
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteor.dtypes      #what types of data does this column holds?
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year            object
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
meteor.tail()    #last 5 observations
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# 45711  01/01/1990 12:00:00 AM  29.03700   17.01850       (29.037, 17.0185)
# 45712  01/01/1999 12:00:00 AM  13.78333    8.96667     (13.78333, 8.96667)
# 45713  01/01/1939 12:00:00 AM  49.25000   17.66667       (49.25, 17.66667)
# 45714  01/01/2003 12:00:00 AM  49.78917   41.50460     (49.78917, 41.5046)
# 45715  01/01/1976 12:00:00 AM  33.98333 -115.68333  (33.98333, -115.68333)

# %%
meteor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45716 entries, 0 to 45715
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         45716 non-null  object
#  1   id           45716 non-null  int64
#  2   nametype     45716 non-null  object
#  3   recclass     45716 non-null  object
#  4   mass (g)     45585 non-null  float64
#  5   fall         45716 non-null  object
#  6   year         45425 non-null  object
#  7   reclat       38401 non-null  float64
#  8   reclong      38401 non-null  float64
#  9   GeoLocation  38401 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.5+ MB

# %%
#exercise 1.1
import pandas as pd
taxis = pd.read_csv('2019_Yellow_Taxi_Trip_Data.csv')
taxis.head(10)      #1st 10 datasets
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
# 5         2  2019-10-23T16:31:12.000  2019-10-23T16:43:20.000
# 6         2  2019-10-23T16:47:10.000  2019-10-23T16:53:17.000
# 7         2  2019-10-23T16:57:35.000  2019-10-23T17:21:28.000
# 8         1  2019-10-23T16:11:36.000  2019-10-23T16:19:33.000
# 9         1  2019-10-23T16:21:48.000  2019-10-23T16:30:04.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# ...

# %%
#exercise 1.2
taxis.dtypes
# Out:
# vendorid                   int64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count            int64
# trip_distance            float64
# ratecodeid                 int64
# store_and_fwd_flag        object
# pulocationid               int64
# dolocationid               int64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# congestion_surcharge     float64
# dtype: object

# %%
#here payment_type is integer. its a categorical variable, we need to change int to obj

taxis.shape
# Out:
# (10000, 18)

# %%
#extracting subsets
meteor.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteor[['name', 'fall']]    #two columns means form of list so it
#gives us 2 columns otherwise 1 column won/t work
# Out:
#              name   fall
# 0          Aachen   Fell
# 1          Aarhus   Fell
# 2            Abee   Fell
# 3        Acapulco   Fell
# 4         Achiras   Fell
# ...           ...    ...
# 45711  Zillah 002  Found
# 45712      Zinder  Found
# 45713        Zlin  Found
# 45714   Zubkovsky  Found
# 45715  Zulu Queen  Found
#
# [45716 rows x 2 columns]

# %%
meteor.loc[:,['name','fall']]   #loc -->refering to column names
                                #iloc-->select rows/columns by their position
# Out:
#              name   fall
# 0          Aachen   Fell
# 1          Aarhus   Fell
# 2            Abee   Fell
# 3        Acapulco   Fell
# 4         Achiras   Fell
# ...           ...    ...
# 45711  Zillah 002  Found
# 45712      Zinder  Found
# 45713        Zlin  Found
# 45714   Zubkovsky  Found
# 45715  Zulu Queen  Found
#
# [45715 rows x 2 columns]

# %%
meteor[100:104]
# Out:
#               name     id nametype       recclass  mass (g)  fall  \
# 100         Benton   5026    Valid            LL6    2840.0  Fell
# 101         Berduc  48975    Valid             L6     270.0  Fell
# 102         Béréba   5028    Valid  Eucrite-mmict   18000.0  Fell
# 103  Berlanguillas   5029    Valid             L6    1440.0  Fell
#
#                        year    reclat   reclong          GeoLocation
# 100  01/01/1949 12:00:00 AM  45.95000 -67.55000      (45.95, -67.55)
# 101  01/01/2008 12:00:00 AM -31.91000 -58.32833  (-31.91, -58.32833)
# 102  01/01/1924 12:00:00 AM  11.65000  -3.65000       (11.65, -3.65)
# 103  01/01/1811 12:00:00 AM  41.68333  -3.80000     (41.68333, -3.8)

# %%
meteor = meteor.drop(100, axis=0)    #drop removes 100 in the below dataset.

# %%
meteor.iloc[100:104,:]
# Out:
#               name     id nametype       recclass  mass (g)  fall  \
# 101         Berduc  48975    Valid             L6     270.0  Fell
# 102         Béréba   5028    Valid  Eucrite-mmict   18000.0  Fell
# 103  Berlanguillas   5029    Valid             L6    1440.0  Fell
# 104       Berthoud  47355    Valid  Eucrite-mmict     960.0  Fell
#
#                        year    reclat    reclong             GeoLocation
# 101  01/01/2008 12:00:00 AM -31.91000  -58.32833     (-31.91, -58.32833)
# 102  01/01/1924 12:00:00 AM  11.65000   -3.65000          (11.65, -3.65)
# 103  01/01/1811 12:00:00 AM  41.68333   -3.80000        (41.68333, -3.8)
# 104  01/01/2004 12:00:00 AM  40.30583 -105.02325  (40.30583, -105.02325)

# %%
meteor['mass (g)']
# Out:
# 0            21.0
# 1           720.0
# 2        107000.0
# 3          1914.0
# 4           780.0
#            ...
# 45711       172.0
# 45712        46.0
# 45713         3.3
# 45714      2167.0
# 45715       200.0
# Name: mass (g), Length: 45715, dtype: float64

# %%
m1 = meteor['mass (g)']>50
meteor[m1]
# Out:
#              name     id nametype     recclass  mass (g)   fall  \
# 1          Aarhus      2    Valid           H6     720.0   Fell
# 2            Abee      6    Valid          EH4  107000.0   Fell
# 3        Acapulco     10    Valid  Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid           L6     780.0   Fell
# 5        Adhi Kot    379    Valid          EH4    4239.0   Fell
# ...           ...    ...      ...          ...       ...    ...
# 45709  Zhongxiang  30406    Valid         Iron  100000.0  Found
# 45710  Zillah 001  31355    Valid           L6    1475.0  Found
# 45711  Zillah 002  31356    Valid      Eucrite     172.0  Found
# 45714   Zubkovsky  31357    Valid           L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid         L3.7     200.0  Found
#
#                          year    reclat    reclong             GeoLocation
# 1      01/01/1951 12:00:00 AM  56.18333   10.23333    (56.18333, 10.23333)
# ...

# %%
#mass>500
#Fall=Fell
m2 = (meteor['mass (g)']>500)| (meteor['fall']=='Fell')
meteor[m2]
# Out:
#              name     id nametype           recclass   mass (g)   fall  \
# 0          Aachen      1    Valid                 L5       21.0   Fell
# 1          Aarhus      2    Valid                 H6      720.0   Fell
# 2            Abee      6    Valid                EH4   107000.0   Fell
# 3        Acapulco     10    Valid        Acapulcoite     1914.0   Fell
# 4         Achiras    370    Valid                 L6      780.0   Fell
# ...           ...    ...      ...                ...        ...    ...
# 45707    Zhaoping  54609    Valid  Iron, IAB complex  2000000.0  Found
# 45708    Zhigansk  30405    Valid        Iron, IIIAB   900000.0  Found
# 45709  Zhongxiang  30406    Valid               Iron   100000.0  Found
# 45710  Zillah 001  31355    Valid                 L6     1475.0  Found
# 45714   Zubkovsky  31357    Valid                 L6     2167.0  Found
#
#                          year    reclat    reclong            GeoLocation
# ...
